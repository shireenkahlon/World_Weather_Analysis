# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df=pd.read_csv("../Resources/cities.csv")
city_data_df
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 0          0           Hilo      US  2021-01-27 21:06:55  19.7297 -155.0900
# 1          1          Grong      NO  2021-01-27 21:06:56  64.4654   12.3149
# 2          2           Chuy      UY  2021-01-27 21:06:56 -33.6971  -53.4616
# 3          3        Houston      US  2021-01-27 21:05:44  29.7633  -95.3633
# 4          4     Georgetown      MY  2021-01-27 21:06:56   5.4112  100.3354
# ..       ...            ...     ...                  ...      ...       ...
# 569      569           Roma      US  2021-01-27 21:04:07  43.2128  -75.4557
# 570      570  Venado Tuerto      AR  2021-01-27 21:09:06 -33.7456  -61.9688
# 571      571        Ituango      CO  2021-01-27 21:09:06   7.1712  -75.7640
# 572      572        Malatya      TR  2021-01-27 21:09:06  38.5000   38.0000
# 573      573         Knysna      ZA  2021-01-27 21:09:07 -34.0363   23.0471
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# ...

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# max_temp=city_data_df["Max Temp"]
# temps=[]
# for temp in max_temp:
#     temps.append(max(temp,0))
    # Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
temps
# Out:
# [73.4,
#  28.4,
#  76.68,
#  68.0,
#  78.01,
#  21.2,
#  0,
#  0,
#  87.21,
#  57.0,
#  28.0,
#  59.0,
#  32.0,
#  52.0,
#  48.99,
#  73.4,
#  79.34,
#  0,
#  72.82,
#  63.93,
#  80.6,
#  61.23,
#  57.2,
#  0,
#  16.66,
#  36.0,
#  73.4,
#  17.76,
#  78.01,
#  62.6,
#  0,
#  46.4,
#  48.99,
#  66.0,
#  60.58,
#  66.2,
#  57.0,
#  78.8,
#  78.58,
#  0,
#  87.8,
#  0,
#  30.0,
#  69.75,
#  25.48,
#  78.84,
#  6.8,
#  48.2,
#  0,
#  72.07,
#  41.0,
#  45.0,
#  0,
#  50.0,
#  0,
#  16.0,
#  21.99,
#  0,
#  78.48,
#  28.4,
#  86.0,
#  87.8,
#  25.0,
#  0,
#  48.2,
#  80.6,
#  64.4,
#  69.01,
#  0,
#  71.29,
#  26.6,
#  26.89,
#  82.4,
#  76.84,
#  66.0,
#  62.11,
#  0,
#  77.0,
#  50.0,
#  79.34,
#  24.8,
#  73.83,
#  57.0,
#  77.76,
#  19.4,
#  77.5,
#  73.45,
#  0,
#  0,
#  51.01,
#  14.0,
#  69.8,
#  3.2,
#  75.6,
#  59.0,
#  84.2,
#  0,
#  39.56,
#  21.99,
#  50.0,
#  33.8,
#  0,
#  77.0,
#  0,
#  44.01,
#  14.07,
#  80.08,
#  84.2,
#  16.02,
#  78.01,
#  55.4,
#  51.01,
#  71.01,
# ...

# %%
import gmaps
# Heatmap of temperature
# Get the latitude and longitude.
locations=city_data_df[["Lat","Lng"]]
# Assign the figure variable.
fig=gmaps.figure(center=(30.0,31.0),zoom_level=1.5)
# Assign the heatmap variable.
heat_layer=gmaps.heatmap_layer(locations,weights=[max(temp,0) for temp in max_temp],dissipating=False,max_intensity=300,point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations=city_data_df[["Lat","Lng"]]
humidity = city_data_df["Humidity"]
fig=gmaps.figure(center=(30.0,31.0),zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations,weights=humidity,dissipating=False,max_intensity=300,point_radius=4,)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
#add locations
locations=city_data_df[["Lat","Lng"]]
#add cloudiness
clouds=city_data_df["Cloudiness"]
#add figure and the basics of what the figure will show
fig=gmaps.figure(center=(30.0,31.0),zoom_level=1.5)
#add heatmap and what is added onto the heatmap
heat_layer=gmaps.heatmap_layer(locations,weights=clouds,dissipating=False,point_radius=1.5,max_intensity=300)
#add heatmap to figure
fig.add_layer(heat_layer)
#call figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#heatmap of windspeed
#add locations
locations=city_data_df[["Lat","Lng"]]
#add wind speed
wind=city_data_df["Wind Speed"]
#add figure which will show the basic maps
fig=gmaps.figure(center=(30.0,31.0),zoom_level=1.5)
#add heat layer which will add the data onto the maps
heat_layer=gmaps.heatmap_layer(locations,weights=wind,dissipating=False,point_radius=1.5,max_intensity=300)
#add the heat layer onto the maps
fig.add_layer(heat_layer)
#call fig
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp=float(input("What is the minimum temperature you would like for your trip? "))
max_temp=float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 80

# %%
preferred_cities_df=city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & (city_data_df["Max Temp"] <= max_temp)]
preferred_cities_df.dropna()
# Out:
#      City_ID        City Country                 Date      Lat       Lng  \
# 0          0        Hilo      US  2021-01-27 21:06:55  19.7297 -155.0900
# 2          2        Chuy      UY  2021-01-27 21:06:56 -33.6971  -53.4616
# 4          4  Georgetown      MY  2021-01-27 21:06:56   5.4112  100.3354
# 15        15       Vaini      TO  2021-01-27 21:03:05 -21.2000 -175.2000
# 16        16     Rikitea      PF  2021-01-27 21:06:59 -23.1203 -134.9692
# ..       ...         ...     ...                  ...      ...       ...
# 547      547       Tacna      PE  2021-01-27 21:05:28 -18.0056  -70.2483
# 549      549  Batticaloa      LK  2021-01-27 21:09:01   7.7102   81.6924
# 555      555   Zacualpan      MX  2021-01-27 21:09:02  21.2500 -105.1667
# 556      556  Sao Filipe      CV  2021-01-27 21:09:03  14.8961  -24.4956
# 564      564     Iquique      CL  2021-01-27 21:09:04 -20.2208  -70.1431
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# ...

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df=preferred_cities_df[["City","Country","Max Temp","Lat","Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#           City Country  Max Temp      Lat       Lng Hotel Name
# 0         Hilo      US     73.40  19.7297 -155.0900
# 2         Chuy      UY     76.68 -33.6971  -53.4616
# 4   Georgetown      MY     78.01   5.4112  100.3354
# 15       Vaini      TO     73.40 -21.2000 -175.2000
# 16     Rikitea      PF     79.34 -23.1203 -134.9692

# %%
# Set parameters to search for a hotel.
params={"radius":5000,
       "type":"lodging",
       "key":g_key}
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 0           Hilo      US     73.40  19.7297 -155.0900
# 2           Chuy      UY     76.68 -33.6971  -53.4616
# 4     Georgetown      MY     78.01   5.4112  100.3354
# 15         Vaini      TO     73.40 -21.2000 -175.2000
# 16       Rikitea      PF     79.34 -23.1203 -134.9692
# 18        Japura      ID     72.82  -0.3167  102.3500
# 26       Kuching      MY     73.40   1.5500  110.3333
# 28   Grand Gaube      MU     78.01 -20.0064   57.6608
# 37  Saint-Pierre      RE     78.80 -21.3393   55.4781
# 38    Port Blair      IN     78.58  11.6667   92.7500
#
#                               Hotel Name
# 0                    Hilo Hawaiian Hotel
# 2                      Nuevo Hotel Plaza
# 4                         Cititel Penang
# 15                   Keleti Beach Resort
# 16                        Pension Maro'i
# 18                      Rumah mbah Jamah
# 26                        Hilton Kuching
# ...

# %%
info_box_template="""
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} F</dd>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots.
locations=hotel_df[["Lat","Lng"]]
max_temp=hotel_df["Max Temp"]
fig=gmaps.figure(center=(30.00,31.00),zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations,weights=max_temp,dissipating=False,point_radius=1.5,max_intensity=300)
marker_layer=gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
